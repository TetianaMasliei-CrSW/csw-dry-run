# %% [markdown]
# title: "CSW test dry-run" subtitle : "CSW dry-run test for contibite to the Notebook Galery." author: "CSW-test: template" tags: [Template] thumbnail: img/test-image-csw.png license: MIT copyright: "© 2024 EUMETSAT

# %% [markdown]
# # CSW test dry-run

# %% [markdown]
# CSW dry-run test. Contrubute the Notebook Gallery
# # Contents
#
# * Objective
# * Data Sources
# * Methods
# * Prerequisites
# * Expected Output

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates a simple structure following the required template.
# Its main goal is to *count apples* in a small dataset.
#
# **Objective:** Verify that users can upload, get approval for, launch, run, and delete custom notebooks using the Notebook Gallery.
# **Data Sources:** Inline Python list.
# **Methods:** Basic Python list operations.
# **Prerequisites:** Python 3, no external libraries needed.
# **Expected Output:** A printed integer representing the number of apples.

# %% [markdown]
# (CSW-test-dry-run.ipynb-Prerequisites)=
# # Prerequisites
#
# This section is inspired by the template from *The Turing Way* Jupyter Book.

# %% [markdown]
# ## Imports

# %%
import sys

# %% [markdown]
# # Your first content section
# Here we begin with a very simple example.

# %%
print("Hello world!")

# %% [markdown]
# ## A content subsection

# %%
a = [1, 2, 3, 4, 5]
[i + 2 for i in a]

# %% [markdown]
# ## Another content subsection
# Now the main apple-counting test.

# %%
fruits = ['apple', 'banana', 'apple', 'orange', 'apple']
apple_count = fruits.count('apple')
apple_count

# %% [markdown]
# # Your second content section
# We have fulfilled the main objective above.

# %% [markdown]
# # Summary
# We demonstrated a structured notebook template and performed a simple test: counting apples.
# The main takeaway is how to follow the template while keeping code sections clean and organized.

# %% [markdown]
# # Resources and references
#
# * The Turing Way Jupyter Book template
# * Python documentation: https://docs.python.org
